# %%
// Scratchpad for duplicateSkeleton logic
public void duplicateSkeleton (SkeletonContext context) {
    if (context == null) return;
    float x = context.x;
    float y = context.y;
    loadSkeleton(context.skeletonFile, context.originalSpineFile, true);
    if (currentSkeleton != null) {
        currentSkeleton.x = x + 50;
        currentSkeleton.y = y;
        
        // Logic to number the duplicated skeleton
        // Need to find how many skeletons have the same base name
        String baseName = context.name != null ? context.name : context.skeletonFile.nameWithoutExtension();
        // Strip existing number if present? Or just append?
        // User said "duplicated skeletons shouuld also be numbered"
        
        // If baseName is "spineboy", next should be "spineboy 2", then "spineboy 3"
        // If baseName is "spineboy 2", next should be "spineboy 3"
        
        // Simple approach: Count how many skeletons start with the base name (minus any number)
        
        // Better approach:
        // 1. Get the name of the source skeleton.
        // 2. Check if it ends with a number.
        // 3. Generate a new name.
        
        String newName = generateUniqueName(baseName);
        currentSkeleton.name = newName;
    }
}

private String generateUniqueName(String baseName) {
    // Regex to find trailing number
    // ...
    return baseName + " X";
}

# %%
// This is a scratchpad, I will use replace_string_in_file for the actual edits.

# %%
# I will define the ParticleInstance class and add it to SkeletonViewer.java
# I'll put it as a static inner class in SkeletonViewer for now, or a separate file if I could, but inner class is easier to manage in one file edit.
# Actually, SkeletonViewer.java is large. I'll add it at the end or near other inner classes.

# %%
# This is a placeholder for the edit_notebook_file tool.
# I will use replace_string_in_file instead as I am editing a java file.

# %%
	void loadParticle (FileHandle file) {
		try {
			ParticleEffect effect = new ParticleEffect();
			effect.load(file, file.parent());
			effect.start();
			particles.add(effect);
			ui.toast("Loaded particle: " + file.name());
		} catch (Exception ex) {
			ex.printStackTrace();
			ui.toast("Error loading particle: " + file.name());
		}
	}
